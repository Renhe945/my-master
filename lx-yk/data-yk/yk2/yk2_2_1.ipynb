# %%
# 项目业务分析：
# 大数据在骨科医疗行业的应用具有巨大的意义。随着医疗科技的不断进步，大数据分析为骨科医疗领域带来了深刻的变革，以下是其重要意义的简要介绍：
# 1. **个性化治疗和预测分析**：大数据分析可以基于病人的历史数据，包括诊断、手术类型、康复过程等，为患者提供个性化的治疗方案。通过分析大规模病例数据，医生可以更准确地预测患者康复的可能情况，有助于提前干预和改善治疗效果。
# 2. **手术规划和优化**：在手术过程中，大数据分析可以帮助医生进行精确的手术规划。通过病例数据库中的手术成功案例和失败案例，医生可以制定更安全和有效的手术策略，减少风险。
# 3. **资源分配和效率提升**：医院和诊所可以利用大数据分析来优化资源分配，确保手术室、床位和医疗设备的最佳利用。这有助于提高医疗服务的效率，减少等待时间，满足更多患者的需求。
# 4. **疾病监测和预防**：通过监测大数据，医疗机构可以更早地发现和识别骨科相关疾病的流行趋势，采取相应的预防措施。这对于预防疾病的传播和控制具有重要意义。
# 5. **研究和医学进展**：大规模的医疗数据集可以用于研究骨科领域的新治疗方法和技术。医学研究人员可以通过分析大数据来发现新的治疗方案，推动医学进步。
# 6. **患者参与和沟通**：大数据分析也促进了患者与医生之间的更紧密合作。患者可以访问他们的医疗数据，了解治疗进展，更好地参与决策，增强了患者和医疗团队之间的沟通。
# 总的来说，大数据在骨科医疗领域的应用不仅提高了治疗质量和效率，还促进了医学研究和患者护理的革命性改进。这些应用展示了大数据对于改善医疗保健体系的巨大潜力和意义。
# 分析数据：
# ```
# 患者ID,患者姓名,年龄,性别,就诊日期,症状,诊断,治疗方案,手术类型,手术医生,手术日期,术前疼痛评分,术后恢复评分,医疗费用,康复计划
# 1,张三,45,男,2023-08-01,关节疼痛,髋关节置换,手术,一级手术,李医生,2023-08-15,7,3,12000,康复锻炼
# 2,李四,60,女,2023-08-02,脊柱疼痛,脊柱融合术,手术,一级手术,王医生,2023-08-20,8,4,15000,康复锻炼
# 3,王五,35,男,2023-08-03,髋关节疼痛,髋关节置换,手术,二级手术,李医生,2023-08-10,6,2,11000,康复锻炼
# 4,赵六,55,女,2023-08-05,膝关节疼痛,膝关节置换,手术,一级手术,刘医生,2023-08-18,7,3,14000,康复锻炼
# 5,刘七,70,男,2023-08-06,脊柱疼痛,脊柱融合术,手术,三级手术,王医生,2023-08-22,9,4,16000,康复锻炼
# 6,陈八,48,女,2023-08-08,髋关节疼痛,髋关节置换,手术,一级手术,李医生,2023-08-14,6,2,13000,康复锻炼
# 7,张九,62,男,2023-08-09,膝关节疼痛,膝关节置换,手术,二级手术,刘医生,2023-08-19,8,3,14500,康复锻炼
# 8,李十,40,女,2023-08-11,脊柱疼痛,脊柱融合术,手术,一级手术,王医生,2023-08-23,7,3,15500,康复锻炼
# 9,王十一,58,男,2023-08-12,髋关节疼痛,髋关节置换,手术,三级手术,李医生,2023-08-16,7,2,12500,康复锻炼
# 10,赵十二,50,女,2023-08-14,脊柱疼痛,脊柱融合术,手术,一级手术,刘医生,2023-08-21,8,4,14800,康复锻炼
# 11,刘十三,47,男,2023-08-15,膝关节疼痛,膝关节置换,手术,二级手术,王医生,2023-08-17,7,3,13500,康复锻炼
# 12,陈十四,63,女,2023-08-17,髋关节疼痛,髋关节置换,手术,二级手术,李医生,2023-08-12,6,2,11200,康复锻炼
# 13,张十五,42,男,2023-08-18,脊柱疼痛,脊柱融合术,手术,一级手术,刘医生,2023-08-24,8,4,15200,康复锻炼
# 14,李十六,68,女,2023-08-20,膝关节疼痛,膝关节置换,手术,三级手术,王医生,2023-08-11,9,3,16200,康复锻炼
# 15,王十七,52,男,2023-08-21,髋关节疼痛,髋关节置换,手术,一级手术,李医生,2023-08-13,7,2,12800,康复锻炼```
# 
# 字段解释：
# 1. **患者ID**: 患者的唯一标识号。
# 2. **患者姓名**: 患者的姓名。
# 3. **年龄**: 患者的年龄。
# 4. **性别**: 患者的性别。
# 5. **就诊日期**: 就诊的日期。
# 6. **症状**: 患者的症状或主诉。
# 7. **诊断**: 医生对患者
# 继续字段解释：
# 
# 7. **诊断**: 医生对患者的诊断结果，例如，髋关节置换、脊柱融合术、膝关节置换等。
# 8. **治疗方案**: 医生为患者提供的治疗方案，可能包括手术或其他治疗方法。
# 9. **手术类型**: 如果治疗方案涉及手术，此处指定手术的类型。
# 10. **手术医生**: 负责执行手术的医生的姓名。
# 11. **手术日期**: 手术实施的日期。
# 12. **术前疼痛评分**: 患者在手术前的疼痛评分，通常用于衡量疼痛程度。
# 13. **术后恢复评分**: 患者在手术后的恢复评分，用于衡量恢复情况。
# 14. **医疗费用**: 就诊和治疗所需的医疗费用。
# 15. **康复计划**: 患者的康复计划，包括康复锻炼或其他康复活动。

# %%
# **业务一：数据ETL过程**（20分）
# 
# **题目1：根据性别统计医疗费用**（5分）
# 编写Python代码，根据性别统计不同性别患者的医疗费用，并将结果以字典形式返回，其中键为性别，值为医疗费用总额。
# 
# **题目2：病人年龄分组与治疗方案**（5分）
# 编写Python代码，将患者根据年龄分组为"年轻"、"中年"和"老年"，然后找出每个年龄段最常用的治疗方案，并将结果以字典形式返回，其中键为年龄段，值为最常用的治疗方案。
# 
# **题目3：计算疼痛评分变化**（5分）
# 编写Python代码，计算每位患者的术前疼痛评分和术后恢复评分的变化，并将结果添加到数据库中。
# 
# **题目4：定义康复计划费用计算函数**（5分）
# 编写Python代码，定义一个函数，根据康复计划的不同类型，计算每位患者的康复计划费用，并展示计算后的结果。

# %%
# **业务二：数据对接和处理**（17分）
# 
# **题目1：使用内置函数计算医疗费用总额**（3分）
# 编写Python代码，使用内置函数计算医疗费用列的总额，并将结果打印出来。代码应包括数据读取、费用总额计算和打印输出。
# 
# **题目2：连接MySQL数据库并添加数据**（5分）
# 编写Python代码，使用MySQL连接库连接到指定数据库，插入三条数据，将插入的数据查询并打印出来。需要包括数据库连接、插入数据影响行数、查询执行和结果全部展示。
# 
# **题目3：统计不同治疗方案的数量**（3分）
# 编写Python代码，统计数据中不同治疗方案的数量，并将结果以字典形式返回，其中键为治疗方案，值为数量。代码应包括数据处理、统计计算和结果返回。
# 
# **题目4：使用OS模块创建文件并写入数据**（3分）
# 编写Python代码，使用OS模块创建一个新的文本文件，并将数据中的年龄和医疗费用信息写入文件中。代码应包括文件创建、数据写入和文件关闭。
# 
# **题目5：定义函数查询数据库并返回结果**（3分）
# 编写Python代码，定义一个函数，该函数接受患者ID作为参数，然后从MySQL数据库中查询该患者的信息，并返回结果。函数应包括数据库连接、查询执行和结果返回。

# %%
# **业务三：数据EDA分析**（25分）
# 
# **题目1：使用NumPy创建医疗费用数组**（5分）
# 编写Python代码，使用NumPy创建一个包含医疗费用数据的NumPy数组，并计算数组的平均值、中位数和标准差。代码应包括NumPy数组的创建、数据分析和结果打印。
# 
# **题目2：Pandas数据整合与筛选**（5分）
# 编写Python代码，自定义年龄、医疗费用筛选患者信息，然后将结果保存到一个新的CSV文件中； 使用Pandas读取数据，并筛选出年龄大于50岁且医疗费用大于10000的患者信息，然后将结果保存到一个新的CSV文件中。代码应包括数据读取、筛选、保存等操作。
# 
# **题目3：使用NumPy计算疼痛评分变化**（5分）
# 编写Python代码，使用NumPy计算每位患者的术前疼痛评分和术后恢复评分的变化，并将结果添加到Pandas数据框中。代码应包括数据处理、计算、数据框操作等步骤。
# 
# **题目4：Pandas数据合并与分组统计**（5分）
# 编写Python代码，使用Pandas将两个数据框合并，一个数据框包含手术医生信息，另一个数据框包含患者信息。然后，根据手术医生进行分组统计每位医生手术的平均医疗费用，并将结果以数据框形式返回。代码应包括数据整合、分组统计等操作。
# 
# **题目5：NumPy和Pandas数据处理函数定义**（5分）
# 编写Python代码，定义一个函数，该函数接受一个NumPy数组作为参数，然后使用Pandas进行数据处理，包括数据筛选、排序和计算。最后，返回处理后的结果数据框。函数应包括数据处理、函数定义和结果返回。

# %%
# **业务四：数据EDA分析展示**（25分）
# 
# **题目1：使用Pandas和Matplotlib绘制医疗费用分布直方图**（5分）
# 编写Python代码，使用Pandas读取数据并使用Matplotlib绘制医疗费用的分布直方图。代码应包括数据读取、数据可视化、图表标签和标题等，并形成分析结论。
# 
# **题目2：使用Pandas进行数据透视和分组统计**（5分）
# 编写Python代码，使用Pandas对数据进行透视操作，计算不同性别和年龄段的医疗费用平均值，并将结果以数据框形式返回。代码应包括数据透视、分组统计等操作，并形成分析结论。
# 
# **题目3：Pandas数据筛选与Matplotlib绘图**（5分）
# 编写Python代码，使用Pandas筛选出年龄大于50岁的患者信息，并使用Matplotlib绘制医疗费用与术前疼痛评分的散点图。代码应包括数据筛选、数据可视化、图表标签和标题等，并形成分析结论。
# 
# **题目4：使用Pandas进行数据合并和绘图**（5分）
# 编写Python代码，使用Pandas将两个数据框合并，一个数据框包含手术医生信息，另一个数据框包含患者信息，然后使用Matplotlib绘制医疗费用与手术医生的关系图。代码应包括数据整合、数据可视化、图表标签和标题等，并形成分析结论。
# 
# **题目5：自定义函数绘制医疗费用与疼痛评分关系图**（5分）
# 编写Python代码，定义一个函数，该函数接受医疗费用和术前疼痛评分作为参数，然后使用Matplotlib绘制医疗费用与术前疼痛评分的关系图。最后，将函数应用于数据，并展示多个关系图。代码应包括函数定义、数据处理、数据可视化等，并形成分析结论。

# %%
# 业务五：数据建模（13分）
# **题目1：使用热力图绘制样本中特征的相关性（2分）
# **题目2：自主在sklearn中选择两种合适的算法，对患者康复状况进行数据建模（8分）
# **题目3：使用最佳模型预测样本数据，并将结果保存CSV（3分）
