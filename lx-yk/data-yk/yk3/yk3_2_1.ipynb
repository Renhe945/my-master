# %%
# 在互联网直播的激烈竞争环境下，仅仅进行直播活动是不够的，了解和分析用户行为数据才能真正提升营销效果。利用直播数据分析，深入洞察用户行为，从而优化营销策略，取得更大的成功,这其中大数据发展和分析发挥着重要的作用，为行业各方提供深入洞察和决策支持。随着直播平台的迅猛发展，大量用户生成的数据被积累，这些数据涵盖了用户观看、互动、行为等多个维度。通过大数据分析，可以实现以下意义：
# 收集关键数据：在直播活动中，收集关键的数据指标是非常重要的一步。通过直播平台提供的统计数据和分析工具，可以获取观众数量、观看时长、互动次数、参与率等数据。此外，还可以使用其他工具，如Google Analytics等，来追踪网站流量、转化率等数据。
# 数据分析与解读：收集到的数据需要进行仔细分析和解读。了解观众的行为模式，比如他们对哪些内容更感兴趣，参与度如何，以及观看时长等指标，可以帮助您了解观众的喜好和需求。通过数据分析，发现潜在的机会和问题，为优化营销策略提供指导。
# 客观评估直播活动效果：通过数据分析，客观评估直播活动的效果。比较不同直播活动之间的关键指标，如观众增长率、留存率、转化率等，找出哪些活动表现较好，哪些需要改进。根据数据评估结果，做出相应的调整和优化，以提升直播活动的效果。
# 个性化推荐和定制化内容：通过数据分析，了解观众的兴趣和偏好，可以为他们提供更个性化的推荐和定制化的内容。根据观众的观看历史、互动记录等数据，精准推荐相关的直播活动和内容，提高观众的参与度和留存率。
# 调整营销策略和优化用户体验：根据数据分析的结果，调整营销策略和优化用户体验。比如，如果数据显示观众对某一类主题的直播活动反应较好，可以增加相关内容的直播活动；如果数据显示观众参与度较低，可以尝试增加互动环节或改善用户体验，以吸引更多观众参与。
# 持续监测和优化：数据分析不是一次性的任务，而是需要持续进行的过程。定期监
# 测和分析直播数据，持续优化营销策略。观察数据的变化趋势，比较不同时间段、不同活动之间的数据差异，找出优化的空间和机会。通过持续的数据监测和优化，不断提升直播活动的效果和用户体验。
# 制定可行的目标和指标：根据数据分析的结果，制定可行的目标和指标。确保目标具体、可衡量，并与营销策略和业务目标相一致。例如，增加观众数量、提高观看时长、增加互动次数等。通过设定目标和跟踪指标，可以更好地衡量营销效果和进展，并对策略进行调整。
# 寻找新的机会和趋势：数据分析不仅可以帮助您优化当前的直播活动，还可以帮助您发现新的机会和趋势。通过观察数据的变化和趋势，分析观众行为和市场需求的变化，及时调整营销策略，抓住新的机会，保持竞争优势。
# 通过直播数据分析，您可以深入了解观众行为，了解他们的兴趣、偏好和需求，优化营销策略，提升直播活动的效果和用户体验。不断收集、分析和应用数据，将使您的直播营销更加精准、有效，取得更好的业绩和市场竞争力。立即开始利用直播数据分析，优化您的营销策略，提升业务成果！
# 数据是当今社会中最重要的资源之_。EDA涉及对数据集进行初步的探索性分析，以了解数据的特征、关系和潛在规律。 通过EDA,我们可以发现数据中的模式、异常值、缺失值等，从而为进一步的数据分析和建模提供指导。
# 第1步：明确问题与目标
# 探索性数据分析总是从提出正确的问题开始。好的问题可以帮助你蒋精力集中在数据的探索，并帮 助你得出有涧察力的见解。
# 第2步：数据收集与清洗
# 我们需要收集相关的数据，并对数据进行清洗和预处理。清洗数据包括处理缺失值、异常值和重复值，确保数据的准确性和一致性。
# 数据清理是数据预处理的一个重要步骡，主要目的是处理原始数据中存在的错误、不完整、重复、 不一致等问题，以便于后续的数据建模与分析。数据清理工作包括数据去重、数据填充、数据转 换、数据归一化、数据筛选、异常值处理等，通过数据清理确保数据的准确性。数据清理可以由专 业数据人员完成，也可以由业务人员自助完成。
# 第3步：探索性分析
# 最有价值的见解来自于不断询问数据问题背后的原因，直到你能够找到解决方案并最终作出有数据 支持的决策。探索性分析使用户能够全面了解数据，快速发现数据模式及趋势、解釋业务原因、发 職务机会，以更好指导业务决策与行动。它包括对数据的探索、可视化和描述性统计分析。通过绘制图表、计算统计指标等方式，我们可以发现数据的分布、趋势和关联性，从而帮助我们理解数据的特征和规律。
# 第4步:假设检验与建模
# 在这一阶段，我们会根据问题和目标进行假设检验和建模分析。通过统计方法和机器学习算法，我们可以验证假设、建立模型并进行预测。这有助于我们发现数据背后的规律和趋势，并作出合理的决策。
# 第5步：可视化数据
# 在完成数据分析后，我们需要对结果进行解释和可视化展示。通过图表、报告和可视化工具，我们可以将复杂的数据分析结果以简洁明了的方式传达给相关的利益相关者。
# 附件说明:  10-1 大数据 大数据系 专高5 《Python数据分析EDA》10月月考技能试题-附件.rar  
# 包含：直播数据集字段说明.docx 和 直播数据集.csv

# %%
# 基础数据分析模块（13分）
#    定义一个名为 `LiveShow` 的Python类，包含属性：直播标题、主播姓名、观看人数、点赞数、评论数、业务方向。类的初始化方法接受这些属性，并提供get_rate方法框架，计算并打印点赞数与观看人数的交互比例（点赞数除以观看人数）（5分）
# 
#    提供cal_person_count方法框架,计算观看人数最高的直播信息并打印（2分）
# 
#    提供方法stat_biz_type方法框架,统计不同业务方向的直播分类并打印（2分）
# 
#    提供get_hot方法框架,根据观看人数，判断直播是否热门（观看人数超过1500），并打印热门直播的信息（2分）
# 
#    提供save方法框架,将观看人数超过1800的直播信息写入名为 `popular_live.txt` 的文本文件（2分）

# %%
# 数据分析ETL模块（40分）
#    使用Pandas读取名为 `直播数据集.csv` ，赋值给数据框变量df中，打印信息内容，中文不能乱码（5分）
# 
#    查看df的描述性统计信息，并统计平均观看时长（2分）
# 
#    删除df中没有“主播姓名”的行，并统计不同业务方向的付费意向（意向=总收入/观看人数）（5分）
# 
#    查看df中的前3行，并统计从点赞->评论->分享的转化率（5分）
# 
#    在df中,使用中位数,填充到"评论数"列中的缺失值,打印df内容（5分） 
# 
#    在df中,使用出现频率最高的分享数填充"分享数"列中的缺失值,打印df内容（5分）
# 
#    实现LiveShow类的get_rate方法并运行打印正确结果（1分）
# 
#    实现LiveShow类的cal_person_count方法并运行打印正确结果（1分）
# 
#    实现LiveShow类的stat_biz_type方法并运行打印正确结果（2分）
# 
#    实现LiveShow类的get_hot方法并运行打印正确结果（1分）
# 
#    实现LiveShow类的save方法并运行显示正确文件名和内容（1分）
# 
#    计算数据中礼物收入的总和并输出结果。（2分）
# 
#    按照观看人数降序排列，并输出排好序的数据。（2分）
# 
#    计算并输出每个直播的总收入（礼物收入 + 广告收入）（3分）

# %%
# 数据分析EDA模块（20分）
#    使用python的numpy、matplotlib、pandas实现以下功能
#    根据数据中的时间和观看人数，绘制折线图展示不同时间点的观看人数趋势，并形成结论。（4分）
# 
#    根据数据中的主播姓名和平均点赞数，绘制柱状图比较不同主播的平均点赞数，并形成结论。（4分）
# 
#    根据数据中的礼物收入和广告收入，绘制饼图展示礼物收入和广告收入在总收入中的占比，并形成结论。（4分）
# 
#    根据数据中的观看人数和点赞数，绘制散点图展示观看人数与点赞数之间的关系，并形成结论。（4分）
# 
#    根据数据中的业务方向和直播时长，绘制箱线图比较不同业务方向的直播时长分布，并形成结论。（4分）

# %%
# 业务数据库交互模块（10分）
#    使用python的numpy、matplotlib、pandas实现以下功能
#    将内容导入MySQL数据库，使用python代码建表并将提供的原始数据插入到名为 `live_data` 的表中。（2分）
# 
#    从数据库中查询所有直播信息，并打印出来。（2分）
# 
#    将观看人数超过1800的直播的业务方向更新为"热门"。（2分）
# 
#    删除评论数少于30或者没有评论的直播信息。（2分）
# 
#    查询直播标题包含"美"的直播信息。（2分）

# %%
# 数据建模模块（17分）
# 1、计算样本特征的相关性（3分）
# 2、将数据拆分成训练集和测试集。（4分）
# 3、自主在sklearn中选择两种合适的算法，对主播的受欢迎程度进行数据建模（6分）
# 3、使用最佳模型预测样本数据，并将结果写入MySQL（4分）
