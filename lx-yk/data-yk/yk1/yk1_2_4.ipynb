# %%
# **分析业务四：数据探索+数据清洗**
# 
# **题目16：年龄与就诊次数关系&年龄数据清洗**（2分）
# 使用Pandas分组将患者年龄分为不同区间，统计每个年龄区间的平均就诊次数，并使用Matplotlib绘制折线图展示。
# 并将患者年龄数据进行清洗，将超过100岁的异常值设置为NaN，并展示清洗后的年龄数据。
# 
# **题目17：疾病与就诊次数关系&就诊次数数据处理**（2分）
# 使用Pandas分组计算不同疾病的平均就诊次数，并使用Matplotlib绘制柱状图展示。
# 并将就诊次数数据按照区间进行处理，将就诊次数小于1的数据设置为1，大于10的数据设置为10，并展示处理后的数据。
# 	
# **题目18：入院日期与费用趋势分析&入院日期数据提取**（3分）
# 使用Pandas按月份分组，计算每个月份的平均医疗费用，并使用Matplotlib绘制折线图展示。
# 并从入院日期中提取出年份和月份两列数据，并将日期格式转换为字符串格式。
# 
# **题目19：不同疾病的治疗方案建议&诊断数据清洗**（3分）
# 根据不同疾病的常见治疗方案，为每个疾病输出相应的治疗方案建议。
# 并将诊断数据中的空值填充为"未知疾病"，并展示清洗后的诊断数据。
# 
# **题目20：医疗费用与治疗方案分析&治疗方案数据处理**（3分）
# 使用Pandas分组计算不同治疗方案的总医疗费用，并使用Matplotlib绘制柱状图展示。
# 并将治疗方案数据进行去重处理，去除重复的方案，并展示处理后的治疗方案数据。
# 
# **题目21：机器学习（共18分）
# ①选择合适的特征，计算样本特征的相关性。（3分）
# ②将数据拆分成训练集和测试集。（4分）
# ③自主在sklearn中选择两种合适的算法，对医疗费用进行数据建模（8分）
# ④使用最佳模型预测样本数据，并将结果保存CSV（3分）
